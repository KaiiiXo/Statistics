# %% [markdown]
# # PANDAS BASICS <hr style="border:2.5px solid #e849a9ff"></hr>

# %% [markdown]
# <b> Ernie Crislyn Ogahayon </b>
# <br> 3rd Year CpET Student

# %% [markdown]
# # IMPORTS AND PACKAGES <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DATAFRAME  <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
data = {
    "Name": ['Jerow', 'Ernie', 'Ag'],
    "Age": [20, 21, 22],
    "Sex": ['M', 'F', 'M']
}

# %%
# creating dataframe from dictionary
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Jerow   20   M
# 1  Ernie   21   F
# 2     Ag   22   M

# %% [markdown]
# # SERIES <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
age_column = df['Age']

# %%
type(age_column)
# Out:
# pandas.core.series.Series

# %%
age_column
# Out:
# 0    20
# 1    21
# 2    22
# Name: Age, dtype: int64

# %%
# Jaguar vs Panther
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
]).T

resistance
# Out:
# array([[10.6, 10.1],
#        [ 9.1, 11. ],
#        [ 9.3,  9.1],
#        [ 9.8, 20. ],
#        [10.5,  9.2],
#        [10.4, 10.8],
#        [ 9.5,  9.9],
#        [11. ,  9.2],
#        [10.4,  9.1],
#        [ 3. ,  9.1],
#        [ 9.8,  nan]])

# %%
# Creating DataFrame from numpy array
df = pd.DataFrame(resistance, columns=["Jaguar", "Panther"])
df
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8      NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Jaguar']
# Out:
# 0     10.6
# 1      9.1
# 2      9.3
# 3      9.8
# 4     10.5
# 5     10.4
# 6      9.5
# 7     11.0
# 8     10.4
# 9      3.0
# 10     9.8
# Name: Jaguar, dtype: float64

# %%
df['Panther']
# Out:
# 0     10.1
# 1     11.0
# 2      9.1
# 3     20.0
# 4      9.2
# 5     10.8
# 6      9.9
# 7      9.2
# 8      9.1
# 9      9.1
# 10     NaN
# Name: Panther, dtype: float64

# %%
# Summary of DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
df.isna()
# Out:
#     Jaguar  Panther
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False
# 4    False    False
# 5    False    False
# 6    False    False
# 7    False    False
# 8    False    False
# 9    False    False
# 10   False     True

# %%
df.isna().sum()
# Out:
# Jaguar     0
# Panther    1
# dtype: int64

# %%
df.dropna()
# Out:
#    Jaguar  Panther
# 0    10.6     10.1
# 1     9.1     11.0
# 2     9.3      9.1
# 3     9.8     20.0
# 4    10.5      9.2
# 5    10.4     10.8
# 6     9.5      9.9
# 7    11.0      9.2
# 8    10.4      9.1
# 9     3.0      9.1

# %%
# Summary of Statistics
df.describe()
# Out:
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    9.400000  10.750000
# std     2.204541   3.329081
# min     3.000000   9.100000
# 25%     9.400000   9.125000
# 50%     9.800000   9.550000
# 75%    10.450000  10.625000
# max    11.000000  20.000000

# %%
# Median
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

print(f'Jaguar Median = {jag_median:.2f} ohms')
print(f'Panther Median = {pan_median:.2f} ohms')
# Out:
# Jaguar Median = 9.80 ohms
# Panther Median = 9.55 ohms

# %%
# Mode
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

# %%
jag_mode
# Out:
# 0     9.8
# 1    10.4
# Name: Jaguar, dtype: float64

# %%
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print("Jaguar Mode:")
for i in jag_mode:
    print(i)
# Out:
# Jaguar Mode:
# 9.8
# 10.4

# %%
print("Panther Mode:")
for i in pan_mode:
    print(i)
# Out:
# Panther Mode:
# 9.1

# %%
# Jaguar IQR
Q1 = df['Jaguar'].quantile(0.25)
Q3 = df['Jaguar'].quantile(0.75)

print(f'Jaguar IQR = {Q3-Q1:.2f} ohms')
# Out:
# Jaguar IQR = 1.05 ohms

# %%
# Panther IQR
Q1 = df['Panther'].quantile(0.25)
Q3 = df['Panther'].quantile(0.75)

print(f'Panther IQR = {Q3-Q1:.2f} ohms')
# Out:
# Panther IQR = 1.50 ohms

# %% [markdown]
# # BAR CHART <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
bars = plt.bar(["Jaguar", "Panther"],
               [jag_mean, pan_mean],)

bars[0].set_color("#e849a9ff")
bars[1].set_color("#e849a9ff")

plt.title('Average Resistance By Machine')
plt.ylabel('Resistance (ohms)')

plt.bar_label(bars, padding=3)
plt.margins(y=0.2)
plt.show()
