# %% [markdown]
# # Lists and Tuples <hr style="border:2.5px solid #e849a9ff"></hr>

# %% [markdown]
# <b> Ernie Crislyn Ogahayon </b>
# <br> 3rd Year CpET Student

# %% [markdown]
# # CREATING A LIST <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
numbers = {1,2,3,4,5}
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
type(numbers)
# Out:
# set

# %%
fruits = {'Apple', 'Banana', 'Grapes'}
fruits
# Out:
# {'Apple', 'Banana', 'Grapes'}

# %%
mixed_list = {10, 'Hello', 2.5, 'Ernie'}
mixed_list
# Out:
# {10, 2.5, 'Ernie', 'Hello'}

# %% [markdown]
# # INDEXING <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
numbers = [1,2,3,4,5]

# %%
numbers[2]
# Out:
# 3

# %%
numbers[-3]
# Out:
# 11

# %% [markdown]
# # MODIFYING ELEMENTS <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits[0] = 'orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
fruits[-2] = 'blueberry'
fruits
# Out:
# ['orange', 'blueberry', 'grape']

# %% [markdown]
# # ADDING ELEMENTS <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# # REMOVING ELEMENTS <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
fruits = ['apple', 'banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
'orange' in fruits
# Out:
# False

# %%
fruits.remove('banana')

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['banana', 'grape']

# %% [markdown]
# # SORT() AND SORTED() <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 2, 1]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # SLICING <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
numbers = [1,3,5,7,9,11,13,15]
numbers
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]

# %%
len(numbers)
# Out:
# 8

# %%
sub = numbers[1:5]
sub
# Out:
# [3, 5, 7, 9]

# %%
numbers[0:8:2]
# Out:
# [1, 5, 9, 13]

# %% [markdown]
# # TUPLE <hr style="border:2.5px solid #e849a9ff"></hr>

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)
